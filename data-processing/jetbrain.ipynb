# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
basic_folder = '/Users/gangbyeongho/Desktop/kang/KHU/전공/2024-1/빅데이터프로젝트/dataset/'

df_jetbrain = pd.read_csv(basic_folder + 'jetBrain.csv')
# Out:
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/2882901221.py:3: DtypeWarning: Columns (11,12,13,16,19,21,26,37,46,47,52,55,57,58,59,79,80,89,91,96,99,105,107,109,113,114,117,118,119,120,126,130,133,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,162,163,171,172,177,179,180,181,185,189,193,194,196,201,206,208,212,214,215,216,218,219,220,224,226,227,228,229,231,233,234,235,236,239,241,242,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,269,270,271,272,273,274,275,276,277,278,279,280,281,282,285,286,287,288,289,290,291,292,293,294,297,298,299,300,303,304,305,306,307,308,313,314,315,316,319,320,321,322,323,324,325,326,329,330,331,332,333,335,336,337,338,339,341,342,343,344,345,346,347,349,350,351,352,357,358,359,360,361,362,363,364,365,367,368,370,371,372,373,374,376,377,378,383,385,387,388,389,390,391,393,395,396,397,398,399,400,401,402,403,404,408,410,411,412,413,414,415,417,418,419,420,421,422,424,425,426,427,428,430,431,432,434,435,436,437,439,440,441,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,472,473,474,475,476,477,478,481,482,483,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,549,550,552,553,554,555,556,557,558,560,561,562,563,564,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,586,587,588,589,590,591,592,593,594,595,598,599,600,601,602,603,604,605,607,609,610,611,612,613,614,615,616,617,618,619,620,621,622,623,624,625,626,627,628,629,630,631,632,633,634,635,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,662,663,664,665,666,668,669,670,671,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,695,696,698,699,700,701,702,703,705,706,707,709,710,711,712,713,714,715,716,717,718,720,721,723,724,725,726,727,728,729,730,731,732,733,734,735,736,737,738,739,740,741,742,743,744,745,746,747,750,751,753,754,755,758,759,760,761,763,764,765,766,767,768,769,770,771,772,774,775,776,777,778,779,780,781,782,787,788,789,790,792,793,794,795,796,797,798,800,801,803,804,805,806,807,808,809,810,814,816,818,819,820,821,824,825,831,841,842,849,850,856,875,882,889,892,893,894,896,900,909,910,911,912,913,914,915,917,918,919,920,921,922,923,924,925,927,928,929,930,931,932,933,934,935,936,937,939,940,941,942,943,944,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,963,964,965,966,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,997,998,1000,1001,1002,1003,1005,1006,1007,1008,1009,1010,1011,1012,1013,1015,1016,1017,1018,1019,1020,1021,1022,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1067,1069,1070,1072,1073,1074,1075,1076,1077,1078,1079,1080,1081,1082,1083,1084,1085,1087,1088,1089,1090,1091,1092,1093,1094,1095,1096,1098,1099,1100,1101,1102,1103,1104,1105,1106,1107,1108,1109,1110,1112,1120,1122,1123,1124,1125,1126,1130,1131,1132,1134,1135,1136,1137,1142,1146,1149,1150,1151,1152,1155,1156,1157,1158,1159,1162,1163,1165,1166,1167,1168,1170,1171,1173,1180,1181,1182,1183,1185,1186,1188,1189,1190,1191,1196,1198,1200,1201,1202,1203,1204,1205,1207,1208,1209,1210,1211,1212,1213,1215,1216,1217,1218,1219,1222,1223,1224,1225,1226,1227,1228,1229,1230,1232,1233,1234,1235,1237,1238,1239,1240,1241,1242,1243,1244,1245,1246,1247,1248,1249,1250,1251,1252,1255,1256,1257,1260,1261,1262,1263,1264,1266,1267,1268,1270,1271,1272,1273,1274,1276,1277,1279,1284,1285,1286,1287,1288,1289,1292,1294,1298,1300,1301,1303,1304,1305,1306,1307,1308,1309,1310,1311,1313,1316,1317,1318,1319,1320,1322, ...
#   df_jetbrain = pd.read_csv(basic_folder + 'jetBrain.csv')

# %%
df_jetbrain
# Out:
#       response_id    weight  \
# 0            qQ5x  1.970867
# 1            jnvX  0.318537
# 2            VVpl  3.875585
# 3            D94r  0.460676
# 4            y3zW  1.172686
# ...           ...       ...
# 29264        PWp4  1.835365
# 29265        mLOO  1.581362
# 29266        nBkm  0.534229
# 29267        2YDG  0.499587
# 29268        3kyj  0.592612
#
#       terms.I have read and I accept these Terms and Conditions  \
# 0      I have read and I accept these Terms and Condi...
# 1      I have read and I accept these Terms and Condi...
# 2      I have read and I accept these Terms and Condi...
# 3      I have read and I accept these Terms and Condi...
# 4      I have read and I accept these Terms and Condi...
# ...                                                  ...
# 29264  I have read and I accept these Terms and Condi...
# 29265  I have read and I accept these Terms and Condi...
# 29266  I have read and I accept these Terms and Condi...
# 29267  I have read and I accept these Terms and Condi...
# 29268  I have read and I accept these Terms and Condi...
#
#               amazon                               employment_status  \
# 0             France  Partially employed by a company / organization
# 1      United States      Fully employed by a company / organization
# 2                NaN      Fully employed by a company / organization
# 3            Germany      Fully employed by a company / organization
# 4                NaN      Fully employed by a company / organization
# ...              ...                                             ...
# 29264            NaN                                         Student
# 29265  United States      Fully employed by a company / organization
# 29266            NaN      Fully employed by a company / organization
# 29267            NaN      Fully employed by a company / organization
# 29268            NaN      Fully employed by a company / organization
#
#       job_role.Developer / Programmer /  Software Engineer  \
# 0            Developer / Programmer /  Software Engineer
# 1            Developer / Programmer /  Software Engineer
# 2            Developer / Programmer /  Software Engineer
# 3            Developer / Programmer /  Software Engineer
# 4            Developer / Programmer /  Software Engineer
# ...                                                  ...
# 29264                                                NaN
# 29265        Developer / Programmer /  Software Engineer
# 29266        Developer / Programmer /  Software Engineer
# 29267        Developer / Programmer /  Software Engineer
# 29268                                                NaN
#
#       job_role.DevOps Engineer / Infrastructure Developer job_role.DBA  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           DBA
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 29264                                                NaN           NaN
# 29265                                                NaN           NaN
# 29266                                                NaN           NaN
# 29267                                                NaN           NaN
# 29268                                                NaN           NaN
#
#       job_role.Architect job_role.Tester / QA Engineer  ... primary.Haskell  \
# 0                    NaN                           NaN  ...             NaN
# 1                    NaN                           NaN  ...             NaN
# 2                    NaN                           NaN  ...             NaN
# 3                    NaN                           NaN  ...             NaN
# 4              Architect                           NaN  ...             NaN
# ...                  ...                           ...  ...             ...
# 29264                NaN                           NaN  ...             NaN
# 29265          Architect                           NaN  ...             NaN
# 29266                NaN                           NaN  ...             NaN
# 29267                NaN                           NaN  ...             NaN
# 29268                NaN                           NaN  ...             NaN
#
#       rank.COBOL primary.I don't use programming languages rank.GraphQL  \
# 0            NaN                                       NaN          NaN
# 1            NaN                                       NaN          NaN
# 2            NaN                                       NaN          NaN
# 3            NaN                                       NaN          NaN
# 4            NaN                                       NaN          NaN
# ...          ...                                       ...          ...
# 29264        NaN                                       NaN          NaN
# 29265        NaN                                       NaN          NaN
# 29266        NaN                                       NaN          NaN
# 29267        NaN                                       NaN          NaN
# 29268        NaN                                       NaN          NaN
#
#         is_employed        main    source  \
# 0          Employed        Dart  internal
# 1          Employed  TypeScript  internal
# 2          Employed         NaN  internal
# 3          Employed          C#  internal
# 4          Employed          C#  internal
# ...             ...         ...       ...
# 29264  Non employed        Java   sharing
# 29265      Employed        Java  internal
# 29266      Employed        Java  internal
# 29267      Employed        Java  internal
# 29268      Employed  HTML / CSS  internal
#
#                                            know_jb_fixed  \
# 0                     I currently use JetBrains products
# 1                     I currently use JetBrains products
# 2                     I currently use JetBrains products
# 3                     I currently use JetBrains products
# 4                     I currently use JetBrains products
# ...                                                  ...
# 29264                 I currently use JetBrains products
# 29265                 I currently use JetBrains products
# 29266                 I currently use JetBrains products
# 29267                 I currently use JetBrains products
# 29268  I have evaluated some JetBrains products, but ...
#
#                                          region salary_group
# 0             Africa, Middle East, Central Asia          NaN
# 1                                 United States  Middle-paid
# 2                                         Japan          NaN
# 3                                       Germany  Middle-paid
# 4                                 United States  Middle-paid
# ...                                         ...          ...
# 29264                                     China          NaN
# 29265                             United States          NaN
# 29266                               South Korea     Low-paid
# 29267               Northern Europe and Benelux          NaN
# 29268  Eastern Europe, Balkans and the Caucasus          NaN
#
# [29269 rows x 3804 columns]

# %%
grouped_columns = {}
for col in df_jetbrain.columns:
    if '.' in col:
        prefix = col.split('.')[0]
        if prefix not in grouped_columns:
            grouped_columns[prefix] = []
        grouped_columns[prefix].append(col)
    else:
        if 'no_prefix' not in grouped_columns:
            grouped_columns['no_prefix'] = []
        grouped_columns['no_prefix'].append(col)

# 새로운 데이터프레임을 담을 딕셔너리 초기화
new_data = pd.DataFrame()

# 그룹화된 컬럼들을 처리
for prefix, cols in grouped_columns.items():
    if prefix != 'no_prefix':
        # 해당 컬럼들을 모아 새로운 데이터프레임 생성
        sub_df = df_jetbrain[cols]
        # NaN이 아닌 값 선택하고, 같은 row에서 여러 값이 있으면 ';'로 연결
        sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
        # 새로운 데이터프레임에 해당 컬럼 추가
        new_data[prefix] = sub_df[prefix]
    else:
        # .이 없는 컬럼은 그대로 추가
        for col in cols:
            new_data[col] = df_jetbrain[col]
# Out:
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[col] = df_jetbrain[col]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df[prefix] = sub_df.apply(lambda row: ';'.join(row.dropna().astype(str)), axis=1)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/969488981.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   new_data[prefix] = sub_df[prefix]

# %%
new_data.shape
# Out:
# (29269, 621)

# %%
new_data.head(5)
# Out:
#   response_id    weight         amazon  \
# 0        qQ5x  1.970867         France
# 1        jnvX  0.318537  United States
# 2        VVpl  3.875585            NaN
# 3        D94r  0.460676        Germany
# 4        y3zW  1.172686            NaN
#
#                                 employment_status position_level  \
# 0  Partially employed by a company / organization         Middle
# 1      Fully employed by a company / organization         Middle
# 2      Fully employed by a company / organization         Middle
# 3      Fully employed by a company / organization         Middle
# 4      Fully employed by a company / organization         Senior
#
#   teaching_what    code_yrs                                    edu_level  \
# 0           NaN   3–5 years                                          NaN
# 1           NaN   3–5 years  Master’s degree (MA, MS, M_Eng_, MBA, etc_)
# 2           NaN  6–10 years                                          NaN
# 3           NaN  6–10 years                                          NaN
# 4           NaN  6–10 years                                          NaN
#
#   age_range        country  ... ps_absorbed_feel_easy_to_get_out  \
# 0     21–29  Other country  ...
# 1     30–39  United States  ...                              5.0
# 2     30–39          Japan  ...
# 3     21–29        Germany  ...                              5.0
# 4     21–29  United States  ...                              1.0
#
#                                        help_prevents  \
# 0
# 1
# 2
# 3
# 4  It’s hard for me to communicate with other peo...
#
#                                           help_howdo  \
# 0
# 1  In-person meeting;Voice/phone call while shari...
# 2
# 3           Voice/phone call while sharing my screen
# 4           Voice/phone call while sharing my screen
#
#   ps_feel_statements_cheerful  ps_feel_statements_relaxed  \
# 0
# 1  More than half of the time  More than half of the time
# 2
# 3  Less than half of the time  Less than half of the time
# 4  More than half of the time  Less than half of the time
#
#     ps_feel_statements_active ps_feel_statements_freshwoked  \
# 0
# 1  Less than half of the time    More than half of the time
# 2
# 3            Some of the time                    At no time
# 4            Most of the time    More than half of the time
#
#   ps_feel_statements_interested                                      primary  \
# 0                                                                       Dart
# 1    More than half of the time  Python;Shell scripting languages;TypeScript
# 2                                                           TypeScript;Go;C#
# 3    Less than half of the time                            TypeScript;SQL;C#
# 4              Most of the time                              TypeScript;C#;C
#
#                                           rank
# 0                                         Dart
# 1  Python;TypeScript;Shell scripting languages
# 2
# 3                            C#;TypeScript;SQL
# 4                              C#;TypeScript;C
#
# [5 rows x 621 columns]

# %%
df_jetbrain.shape
# Out:
# (29269, 3804)

# %%
df_jetbrain.head(5)
# Out:
#   response_id    weight  \
# 0        qQ5x  1.970867
# 1        jnvX  0.318537
# 2        VVpl  3.875585
# 3        D94r  0.460676
# 4        y3zW  1.172686
#
#   terms.I have read and I accept these Terms and Conditions         amazon  \
# 0  I have read and I accept these Terms and Condi...                France
# 1  I have read and I accept these Terms and Condi...         United States
# 2  I have read and I accept these Terms and Condi...                   NaN
# 3  I have read and I accept these Terms and Condi...               Germany
# 4  I have read and I accept these Terms and Condi...                   NaN
#
#                                 employment_status  \
# 0  Partially employed by a company / organization
# 1      Fully employed by a company / organization
# 2      Fully employed by a company / organization
# 3      Fully employed by a company / organization
# 4      Fully employed by a company / organization
#
#   job_role.Developer / Programmer /  Software Engineer  \
# 0        Developer / Programmer /  Software Engineer
# 1        Developer / Programmer /  Software Engineer
# 2        Developer / Programmer /  Software Engineer
# 3        Developer / Programmer /  Software Engineer
# 4        Developer / Programmer /  Software Engineer
#
#   job_role.DevOps Engineer / Infrastructure Developer job_role.DBA  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                                                NaN           DBA
# 4                                                NaN           NaN
#
#   job_role.Architect job_role.Tester / QA Engineer  ... primary.Haskell  \
# 0                NaN                           NaN  ...             NaN
# 1                NaN                           NaN  ...             NaN
# 2                NaN                           NaN  ...             NaN
# 3                NaN                           NaN  ...             NaN
# 4          Architect                           NaN  ...             NaN
#
#   rank.COBOL primary.I don't use programming languages rank.GraphQL  \
# 0        NaN                                       NaN          NaN
# 1        NaN                                       NaN          NaN
# 2        NaN                                       NaN          NaN
# 3        NaN                                       NaN          NaN
# 4        NaN                                       NaN          NaN
#
#   is_employed        main    source                       know_jb_fixed  \
# 0    Employed        Dart  internal  I currently use JetBrains products
# 1    Employed  TypeScript  internal  I currently use JetBrains products
# 2    Employed         NaN  internal  I currently use JetBrains products
# 3    Employed          C#  internal  I currently use JetBrains products
# 4    Employed          C#  internal  I currently use JetBrains products
#
#                               region salary_group
# 0  Africa, Middle East, Central Asia          NaN
# 1                      United States  Middle-paid
# 2                              Japan          NaN
# 3                            Germany  Middle-paid
# 4                      United States  Middle-paid
#
# [5 rows x 3804 columns]

# %% [markdown]
# ##  'position_level'에 따라 데이터 분리 (Junior, MIddle, Senior)

# %%
middle_df = new_data[new_data['position_level'] == 'Middle']
senior_df = new_data[new_data['position_level'] == 'Senior']
junior_df = new_data[new_data['position_level'] == 'Junior']


middle_df.to_csv('../../created_csv/jetbrain_middle.csv', index=False)
senior_df.to_csv('../../created_csv/jetbrain_senior.csv', index=False)
junior_df.to_csv('../../created_csv/jetbrain_junior.csv', index=False)

# %%
junior_df.head(5)
# Out:
#    response_id    weight  amazon  \
# 8         2YDV  0.589748     NaN
# 9         3ky9  0.371278  France
# 18        XkdN  0.321475     NaN
# 25        oB5L  0.586052     NaN
# 47        PW76  1.790546     NaN
#
#                                     employment_status position_level  \
# 8          Fully employed by a company / organization         Junior
# 9                                     Working student         Junior
# 18                                    Working student         Junior
# 25         Fully employed by a company / organization         Junior
# 47  Freelancer (a person pursuing a profession wit...         Junior
#
#    teaching_what   code_yrs                                    edu_level  \
# 8            NaN  1–2 years  Master’s degree (MA, MS, M_Eng_, MBA, etc_)
# 9            NaN  1–2 years     Bachelor’s degree (BA, BS, B_Eng_, etc_)
# 18           NaN  3–5 years                                          NaN
# 25           NaN  1–2 years  Master’s degree (MA, MS, M_Eng_, MBA, etc_)
# 47           NaN  3–5 years  Master’s degree (MA, MS, M_Eng_, MBA, etc_)
#
#    age_range        country  ... ps_absorbed_feel_easy_to_get_out  \
# 8      21–29         France  ...
# 9      18–20         France  ...
# 18     21–29         Poland  ...
# 25     21–29        Germany  ...
# 47     21–29  Other country  ...
#
#    help_prevents help_howdo ps_feel_statements_cheerful  \
# 8
# 9
# 18
# 25
# 47
#
#    ps_feel_statements_relaxed ps_feel_statements_active  \
# 8
# 9
# 18
# 25
# 47
#
#    ps_feel_statements_freshwoked ps_feel_statements_interested  \
# 8
# 9
# 18
# 25
# 47
#
#                                primary                                rank
# 8   Shell scripting languages;Java;SQL  Java;Shell scripting languages;SQL
# 9            JavaScript;PHP;HTML / CSS           PHP;JavaScript;HTML / CSS
# 18          JavaScript;HTML / CSS;Ruby          JavaScript;Ruby;HTML / CSS
# 25                                  C#                                  C#
# 47        Python;TypeScript;JavaScript        Python;TypeScript;JavaScript
#
# [5 rows x 621 columns]

# %% [markdown]
# ## JetBrain 응답별로 필요한 데이터 셋 가져오기
# Jetbrain에서 제공해주는 데이터가 현재 두 개가 있습니다. 해당 데이터가 같은 설문조사임에도 분리가 되어 있어서 이 중 필요한 다음의 정보를 전처리하여 병합하는 과정을 거칩니다.
#
# - lifstyle_sleep
# - job_code
# - learn_time
# - job_productive

# %% [markdown]
# job_productive의 경우 job_productive.{hobby} 의 데이터로 존재하여 이것을 묶어서 hobby를 value로 처리 필요

# %%
# 분리된 jetbrain 데이터 read
df_jetbrain2 = pd.read_csv(basic_folder + 'jet_brain.csv')

# %%
df_jetbrain2.shape
# Out:
# (5242607, 4)

# %%
df_jetbrain2.head(100)
# Out:
#    response_id                                           variable  \
# 0         qQ5x  terms.I have read and I accept these Terms and...
# 1         qQ5x                                             amazon
# 2         qQ5x                                  employment_status
# 3         qQ5x  job_role.Developer / Programmer /  Software En...
# 4         qQ5x                                     position_level
# ..         ...                                                ...
# 95        qQ5x               pairprog_tools_remote.Remote desktop
# 96        qQ5x                     pairprog_for.Teaching sessions
# 97        qQ5x                      pairprog_for.When I need help
# 98        qQ5x  ci_jenkins.Company.Which Continuous Integratio...
# 99        qQ5x  ci_github_actions.Personal use.Which Continuou...
#
#                                                 value    weight
# 0   I have read and I accept these Terms and Condi...  1.970867
# 1                                              France  1.970867
# 2      Partially employed by a company / organization  1.970867
# 3         Developer / Programmer /  Software Engineer  1.970867
# 4                                              Middle  1.970867
# ..                                                ...       ...
# 95                                     Remote desktop  1.970867
# 96                                  Teaching sessions  1.970867
# 97                                   When I need help  1.970867
# 98                                            Company  1.970867
# 99                                       Personal use  1.970867
#
# [100 rows x 4 columns]

# %%
# job_productive로 시작하는 변수 필터링
job_productive_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('job_productive')]
job_productive_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

productive_list = job_productive_df['variable'].unique().tolist()
other_list = ['lifestyle_sleep', 'job_code', 'learn_time']

include_list = productive_list + other_list

jetbrain_filtered_df = df_jetbrain2[df_jetbrain2['variable'].isin(include_list)]
jetbrain_filtered_df.head(5)
# Out:
#      response_id              variable              value    weight
# 174         qQ5x       lifestyle_sleep          6-7 hours  1.970867
# 318         jnvX            learn_time  9–16 hours a week  0.318537
# 864         y3zW            learn_time  9–16 hours a week  1.172686
# 1052        PWp6              job_code      Less than 10%  0.222448
# 1057        PWp6  job_productive.Music              Music  0.222448

# %% [markdown]
# job_productive.{hobby} variable의 value들 모두 job_productive로 변경

# %%
jetbrain_filtered_df['variable'] = jetbrain_filtered_df['variable'].str.split('.').str[0]
jetbrain_filtered_df.head(10)
# Out:
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/3164448730.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jetbrain_filtered_df['variable'] = jetbrain_filtered_df['variable'].str.split('.').str[0]
#      response_id         variable              value    weight
# 174         qQ5x  lifestyle_sleep          6-7 hours  1.970867
# 318         jnvX       learn_time  9–16 hours a week  0.318537
# 864         y3zW       learn_time  9–16 hours a week  1.172686
# 1052        PWp6         job_code      Less than 10%  0.222448
# 1057        PWp6   job_productive              Music  0.222448
# 1058        PWp6   job_productive           Sleeping  0.222448
# 1059        PWp6   job_productive            Hobbies  0.222448
# 1060        PWp6   job_productive            Walking  0.222448
# 1517        2YDV         job_code            31%-40%  0.589748
# 1522        2YDV   job_productive              Music  0.589748

# %%
jetbrain_pivot_df = jetbrain_filtered_df.pivot_table(index='response_id', columns='variable', values='value', aggfunc='first')
jetbrain_pivot_df.reset_index()
# Out:
# variable response_id       job_code job_productive        learn_time  \
# 0               011A        71%-80%         Coffee               NaN
# 1               012q        41%-50%         Coffee               NaN
# 2               0161        31%-40%       Sleeping               NaN
# 3               017Z        61%-70%         Coffee               NaN
# 4               01Aq        71%-80%         Coffee  3–8 hours a week
# ...              ...            ...            ...               ...
# 10613           zymY        21%-30%         Coffee               NaN
# 10614           zyo8  Less than 10%          Music               NaN
# 10615           zyvy        51%-60%         Coffee               NaN
# 10616           zyxe        10%-20%         Coffee  1–2 hours a week
# 10617            zz0        81%-90%         Coffee               NaN
#
# variable lifestyle_sleep
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 10613                NaN
# 10614                NaN
# 10615          5-6 hours
# 10616                NaN
# 10617                NaN
#
# [10618 rows x 5 columns]

# %%
jetbrain_pivot_df.head(100)
# Out:
# variable          job_code job_productive        learn_time lifestyle_sleep
# response_id
# 011A               71%-80%         Coffee               NaN             NaN
# 012q               41%-50%         Coffee               NaN             NaN
# 0161               31%-40%       Sleeping               NaN             NaN
# 017Z               61%-70%         Coffee               NaN             NaN
# 01Aq               71%-80%         Coffee  3–8 hours a week             NaN
# ...                    ...            ...               ...             ...
# 0OWq               71%-80%         Coffee               NaN       7-8 hours
# 0Oev         More than 90%         Coffee               NaN             NaN
# 0OrA               61%-70%         Coffee  3–8 hours a week             NaN
# 0Oyq               21%-30%         Coffee               NaN       5-6 hours
# 0Pv                51%-60%         Coffee               NaN             NaN
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 각 variable별 고유값 추출

# %%
unique_values = {col: jetbrain_pivot_df[col].dropna().unique().tolist() for col in jetbrain_pivot_df.columns}
unique_values['job_code']
# Out:
# ['71%-80%',
#  '41%-50%',
#  '31%-40%',
#  '61%-70%',
#  '21%-30%',
#  '51%-60%',
#  '10%-20%',
#  '81%-90%',
#  'More than 90%',
#  'Less than 10%']

# %%
unique_values['learn_time']
# Out:
# ['3–8 hours a week',
#  '9–16 hours a week',
#  '1–2 hours a week',
#  '32 hours a week or more',
#  '17–32 hours a week',
#  'Less than 1 hour a week']

# %%
unique_values['lifestyle_sleep']
# Out:
# ['7-8 hours',
#  '6-7 hours',
#  '4-5 hours',
#  'More than 9 hours',
#  '5-6 hours',
#  '8-9 hours',
#  'Less than 4 hours']

# %%
unique_values['job_productive']
# Out:
# ['Coffee',
#  'Sleeping',
#  'Music',
#  'Snacking',
#  'Pets',
#  'Other',
#  'Walking',
#  'Hobbies',
#  'Smoking',
#  'Alcohol']

# %% [markdown]
# ### 두 csv에서 추출한 DataFrame에서 response_id 매칭시키기

# %%
junior_jetbrain_merged_df = pd.merge(junior_df, jetbrain_pivot_df, on='response_id', how='left') # new data -> junior df -> merged df
middle_jetbrain_merged_df = pd.merge(middle_df, jetbrain_pivot_df, on='response_id', how='left') # new data -> junior df -> merged df
senior_jetbrain_merged_df = pd.merge(senior_df, jetbrain_pivot_df, on='response_id', how='left') # new data -> junior df -> merged df

# %%
junior_jetbrain_merged_df.shape
# Out:
# (4068, 625)

# %%
middle_jetbrain_merged_df.shape
# Out:
# (7257, 625)

# %%
senior_jetbrain_merged_df.shape
# Out:
# (10536, 625)

# %% [markdown]
# 위의 job_productive와 동일하게 데이터 처리(deprecated)

# %%
activities_kinds_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('activities_kinds')]
activities_kinds_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

# %%
# sw_types_developed

sw_types_developed_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('sw_types_developed')]
sw_types_developed_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

# %%
# jb_prod_use

jb_prod_use_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('jb_prod_use')]
jb_prod_use_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

# %%
primary_proglang_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('primary_proglang')]
primary_proglang_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

adopt_proglang_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('adopt_proglang')]
adopt_proglang_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

r_ide_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('r_ide')]
r_ide_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

db_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('db')]
db_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

regularly_tools_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('regularly_tools')]
regularly_tools_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

communication_tools_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('communication_tools')]
communication_tools_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

ides_df = df_jetbrain2[df_jetbrain2['variable'].str.startswith('ides')]
ides_values = list(set(job_productive_df['value'])) # job_pruductive 응답 데이터

# %% [markdown]
# - primary_proglang
# - adopt_proglang
# - r_ide
# - db
# - regularly_tools
# - communication_tools
# - ides

# %% [markdown]
# ### group열 생성 및 추가

# %% [markdown]
# 필요없는 컬럼들 삭제

# %%
junior_jetbrain_groupby_job_role_df = junior_jetbrain_merged_df.groupby('job_role')
middle_jetbrain_groupby_job_role_df = middle_jetbrain_merged_df.groupby('job_role')
senior_jetbrain_groupby_job_role_df = senior_jetbrain_merged_df.groupby('job_role')

# %%
junior_jetbrain_groupby_job_role_df

# %%
middle_jetbrain_groupby_job_role_df.size()
# Out:
# job_role
# Architect;Business Analyst;Team Lead;Product Manager / Marketing Manager                                                        1
# Architect;Business Analyst;Technical Writer                                                                                     1
# Architect;Data Analyst / Data Engineer/ Data Scientist                                                                          1
# Architect;Data Analyst / Data Engineer/ Data Scientist;Business Analyst;Systems Analyst                                         1
# Architect;Data Analyst / Data Engineer/ Data Scientist;Business Analyst;Systems Analyst;Product Manager / Marketing Manager     1
#                                                                                                                                ..
# Tester / QA Engineer;Technical Writer;Systems Analyst;Instructor / Teacher / Tutor                                              1
# Tester / QA Engineer;UX / UI Designer;Developer Advocate                                                                        1
# UX / UI Designer                                                                                                               36
# UX / UI Designer;Developer Advocate                                                                                             2
# UX / UI Designer;Other                                                                                                          1
# Length: 444, dtype: int64

# %%
junior_jetbrain_groupby_job_role_df.size()
# Out:
# job_role
# Architect;Business Analyst;Systems Analyst                                            1
# Architect;Technical Support;Systems Analyst;Developer Advocate                        1
# Architect;Tester / QA Engineer;Technical Support;Technical Writer;Systems Analyst     1
# Architect;Tester / QA Engineer;UX / UI Designer                                       1
# Business Analyst                                                                     20
#                                                                                      ..
# Tester / QA Engineer;Product Manager / Marketing Manager                              2
# Tester / QA Engineer;Systems Analyst                                                  2
# Tester / QA Engineer;Technical Support                                                2
# Tester / QA Engineer;UX / UI Designer                                                 1
# UX / UI Designer                                                                     26
# Length: 199, dtype: int64

# %% [markdown]
# - edu_level
# - age_range
# - gender
# - edu_type_of_inst
# - edu_degree
# - edu_major_sub
# - ide_main
# - edu_resources
# <!-- - learn_time_x -->
# - job_satisfied
# <!-- - job_code_x -->
# <!-- - life_sleep_x -->
# - work_day_start
# - lifestyle_bedtime
# - main
# - source
# - os_devenv
# - activities_kinds
# - target_platforms
# - sw_types_developed
# - primary_proglang
# - target_platforms_web_(back-end)
# - target_platforms_cloud
# - target_platforms_iot_/_embedded
# - target_platforms_web_(front-end)
# - target_platforms_server_/_infrastructure
# - target_platforms_consoles_(xbox_/_playstation_/_nintendo_etc
# - sw_developed_types_augmented_reality_/_virtual_reality
# - sw_developed_types_business_intelligence_/_data_science_/_machine_learning
# - sw_developed_types_blockchain
# - sw_developed_types_database_/_data_storage
# - sw_developed_types_games
# - sw_developed_types_it_infrastructure
# - db
# - test_types
# - regularly_tools
# - communication_tools
# - ides
# - sql_tool
# - sectors_it
# - kind_of_dev
# - lifestyle_hobbies
# - job_important
# - primary
# - job_code_y
# - job_productive_y
# - learn_time_y
# - lifestyle_sleep_y

# %%
parsed_col_list = ['edu_level',
'age_range',
'gender',
'edu_type_of_inst',
'edu_degree',
'edu_major_sub',
'ide_main',
'edu_resources',
'job_satisfied',
'work_day_start',
'lifestyle_bedtime',
'main',
'source',
'job_role',
'os_devenv',
'activities_kinds',
'target_platforms',
'sw_types_developed',
'primary_proglang',
'target_platforms_web_(back-end)',
'target_platforms_cloud',
'target_platforms_iot_/_embedded',
'target_platforms_web_(front-end)',
'target_platforms_server_/_infrastructure',
'target_platforms_consoles_(xbox_/_playstation_/_nintendo_etc',
'sw_developed_types_augmented_reality_/_virtual_reality',
'sw_developed_types_business_intelligence_/_data_science_/_machine_learning',
'sw_developed_types_blockchain',
'sw_developed_types_database_/_data_storage',
'sw_developed_types_games',
'sw_developed_types_it_infrastructure',
'db',
'test_types',
'regularly_tools',
'communication_tools',
'ides',
'sql_tool',
'sectors_it',
'kind_of_dev',
'lifestyle_hobbies',
'job_important',
'primary',
'job_code_y',
'job_productive_y',
'learn_time_y',
'lifestyle_sleep_y']

# %%
try:
    # 특정 컬럼들만 선택하여 새로운 데이터프레임 생성
    parsed_junior_jetbrain_df = junior_jetbrain_merged_df[parsed_col_list]
    parsed_middle_jetbrain_df = middle_jetbrain_merged_df[parsed_col_list]
    parsed_senior_jetbrain_df = senior_jetbrain_merged_df[parsed_col_list]
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# 'UX / UI Designer' 랑 'Developer / Programmer /  Software Engineer' 데이터는 유지

# %%
# 특정 문자열을 하나의 단어로 고려하여 분리하도록 수정된 함수
def split_job_roles(row):
    # 유지할 문자열 패턴 정의
    keep_patterns = [
        'Developer / Programmer /  Software Engineer',
        'UX / UI Designer',
        'Tester / QA Engineer'
    ]
    
    job_roles = []
    # ; 로 우선 분리
    roles = row['job_role'].split(';')
    
    for role in roles:
        # 유지할 문자열이 아닌 경우에만 / 로 분리
        if role.strip() not in keep_patterns:
            sub_roles = re.split(r' / ', role)
            for sub_role in sub_roles:
                job_roles.append(sub_role.strip())
        else:
            job_roles.append(role.strip())
    
    new_rows = []
    for job in job_roles:
        new_row = row.copy()
        new_row['job'] = job
        new_rows.append(new_row)
    
    return new_rows

# %% [markdown]
# ### job전환

# %%
new_junior_rows = []
new_middle_rows = []
new_senior_rows = []

for _, row in parsed_junior_jetbrain_df.iterrows():
    new_junior_rows.extend(split_job_roles(row))


for _, row in parsed_middle_jetbrain_df.iterrows():
    new_middle_rows.extend(split_job_roles(row))


for _, row in parsed_senior_jetbrain_df.iterrows():
    new_senior_rows.extend(split_job_roles(row))

# %%
junior_expanded_df = pd.DataFrame(new_junior_rows)
junior_expanded_df = junior_expanded_df.drop(columns=['job_role'])

middle_expanded_df = pd.DataFrame(new_middle_rows)
middle_expanded_df = middle_expanded_df.drop(columns=['job_role'])

senior_expanded_df = pd.DataFrame(new_senior_rows)
senior_expanded_df = senior_expanded_df.drop(columns=['job_role'])

# %% [markdown]
# 겹업할 수 있다고 판단하여 response별로가 아닌 job별로 extend

# %%
junior_unique_values = junior_expanded_df['job'].unique()
junior_unique_values_df = pd.DataFrame(junior_unique_values, columns=['unique_job_roles'])

middle_unique_values = middle_expanded_df['job'].unique()
middle_unique_values_df = pd.DataFrame(middle_unique_values, columns=['unique_job_roles'])

senior_unique_values = senior_expanded_df['job'].unique()
senior_unique_values_df = pd.DataFrame(senior_unique_values, columns=['unique_job_roles'])

# %%
middle_unique_values_df
# Out:
#                                unique_job_roles
# 0   Developer / Programmer /  Software Engineer
# 1                                           DBA
# 2                               DevOps Engineer
# 3                      Infrastructure Developer
# 4                              UX / UI Designer
# 5                                  Data Analyst
# 6                 Data Engineer/ Data Scientist
# 7                             Technical Support
# 8                                     Architect
# 9                                     Team Lead
# 10                             Technical Writer
# 11                         Tester / QA Engineer
# 12                                   Instructor
# 13                                      Teacher
# 14                                        Tutor
# 15                                          CIO
# 16                                          CEO
# 17                                          CTO
# 18                              Systems Analyst
# 19                              Product Manager
# 20                            Marketing Manager
# 21                                        Other
# 22                             Business Analyst
# 23                           Developer Advocate

# %%
senior_unique_values_df
# Out:
#                                unique_job_roles
# 0   Developer / Programmer /  Software Engineer
# 1                                     Architect
# 2                                     Team Lead
# 3                                  Data Analyst
# 4                 Data Engineer/ Data Scientist
# 5                               Systems Analyst
# 6                          Tester / QA Engineer
# 7                               DevOps Engineer
# 8                      Infrastructure Developer
# 9                              Technical Writer
# 10                                   Instructor
# 11                                      Teacher
# 12                                        Tutor
# 13                                          CIO
# 14                                          CEO
# 15                                          CTO
# 16                            Technical Support
# 17                             UX / UI Designer
# 18                           Developer Advocate
# 19                              Product Manager
# 20                            Marketing Manager
# 21                                          DBA
# 22                             Business Analyst
# 23                                        Other

# %%
# 위에서 junir, middle, senior expaneded df to csv 
# expanded_df.to_csv('../created_csv/jetbrain_filtered_df.csv')

# %% [markdown]
# Developer / Programmer /  Software Engineer 의 조합을 통해 구체적인 개발자 직종 나누기
# - Developer / Programmer /  Software Engineer + Blockchain => BlockChcin
# - Developer / Programmer /  Software Engineer + Web (Back-end) => Developer, back-end
# - Developer / Programmer /  Software Engineer + Web (Front-end) => Developer, front-end
# - Developer / Programmer /  Software Engineer + Web (Back-end) && Web (Front-end) => Developer, full-stack
# - Developer / Programmer /  Software Engineer + Games => Developer, game or graphics
# - Developer / Programmer /  Software Engineer + Mobile => Developer, mobile

# %%
# 조합에 따른 새로운 컬럼 생성 함수
def create_specific_job(row):
    try:
        job_role = row['job']
        target_platforms = row['target_platforms']
        if 'Developer / Programmer /  Software Engineer' == job_role:
            if 'Blockchain' in target_platforms:
                row['job'] = 'BlockChain'
                row['target_platforms'] = 'Blockchain'
            elif 'Web (Back-end)' in target_platforms and 'Web (Front-end)' in target_platforms:
                row['job'] = 'Developer, full-stack'
                row['target_platforms'] = 'Web (Full-stack)'
            elif 'Web (Back-end)' in target_platforms:
                row['job'] = 'Developer, back-end'
                row['target_platforms'] = 'Web (Back-end)'
            elif 'Web (Front-end)' in target_platforms:
                row['job'] = 'Developer, front-end'
                row['target_platforms'] = 'Web (Front-end)'
            elif 'Games' in target_platforms:
                row['job'] = 'Developer, game or graphics'
                row['target_platforms'] = 'Games'
            elif 'Mobile' in target_platforms:
                row['job'] = 'Developer, mobile'
                row['target_platforms'] = 'Mobile'
            else:
                row['job'] = 'Developer / Programmer /  Software Engineer'
                row['target_platforms'] = row['target_platforms']
        else:
            if job_role == 'UX / UI Designer':
                row['job'] = 'UX / UI Designer'
            elif job_role == 'Data Engineer':
                row['job'] = 'Engineer, data'
            elif job_role == 'DBA':
                row['job'] = 'Database administrator'
            elif job_role == 'Tester' or job_role == 'QA Engineer':
                row['job'] = 'Developer, QA or test'
            elif job_role == 'Data Scientist':
                row['job'] = 'Data scientist or machine learning specialist'
            elif job_role == 'Data Analyst' or job_role == 'Business Analyst':
                row['job'] = 'Data or business analyst'
            elif job_role == 'DevOps Engineer':
                row['job'] = 'DevOps specialist'
            else:
                row['job'] = job_role
                row['target_platforms'] = row['target_platforms']
        return row
    except Exception as e:
        print(e)

# %%
junior_new_df = junior_expanded_df.apply(create_specific_job, axis=1)
middle_new_df = middle_expanded_df.apply(create_specific_job, axis=1)
senior_new_df = senior_expanded_df.apply(create_specific_job, axis=1)

# %% [markdown]
# - BlockChain
# - Developer, full-stack
# - Developer, back-end
# - Developer, front-end
# - Developer, game or graphics
# - Developer, mobile
# - UX / UI Designer
# - Engineer, data
# - Database administrator
# - Data scientist or machine learning specialist
# - Data or business analyst
# - Product manager
# - Developer Advocate
# - Developer, QA or test
# - DevOps specialist

# %%
filtered_job_list = [
'BlockChain',
'Developer, full-stack',
'Developer, back-end',
'Developer, front-end',
'Developer, game or graphics',
'Developer, mobile',
'UX / UI Designer',
'Engineer, data',
'Database administrator',
'Data scientist or machine learning specialist',
'Data or business analyst',
'Product manager',
'Developer Advocate',
'Developer, QA or test',
'DevOps specialist'
]

# %%
junior_filtered_by_joblist_df = junior_new_df[junior_new_df['job'].isin(filtered_job_list)]
middle_filtered_by_joblist_df = middle_new_df[middle_new_df['job'].isin(filtered_job_list)]
senior_filtered_by_joblist_df = senior_new_df[senior_new_df['job'].isin(filtered_job_list)]

# %%
junior_filtered_by_joblist_df.shape
# Out:
# (4103, 46)

# %% [markdown]
# ### 최종 정리 데이터 {position_level}_filtered_by_joblist_df

# %%
def func(group):
    new_group = pd.DataFrame({
        'job_code' : group['job_code_y'],
        'learn_time' : group['learn_time_y'],
        'lifestyle_sleep' : group['lifestyle_sleep_y'],
        'productive_to_job' : group['job_productive_y'],
        'primary_proglang' : group['primary_proglang'],
        'job_satisfied' : group['job_satisfied'],
        'edu_level': group['edu_level'],
        'ide_main': group['ide_main'],
        'db' : group['db']
    })

    return new_group

# %%
junior_filtered_by_joblist_df.groupby(['job'])
junior_result_group_by_job = junior_filtered_by_joblist_df.groupby(['job']).apply(func)

middle_filtered_by_joblist_df.groupby(['job'])
middle_result_group_by_job = middle_filtered_by_joblist_df.groupby(['job']).apply(func)

senior_filtered_by_joblist_df.groupby(['job'])
senior_result_group_by_job = senior_filtered_by_joblist_df.groupby(['job']).apply(func)
# Out:
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/2655241815.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   junior_result_group_by_job = junior_filtered_by_joblist_df.groupby(['job']).apply(func)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/2655241815.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   middle_result_group_by_job = middle_filtered_by_joblist_df.groupby(['job']).apply(func)
# /var/folders/gg/4qp_rmh142s9_kw6c0456bq00000gn/T/ipykernel_50550/2655241815.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   senior_result_group_by_job = senior_filtered_by_joblist_df.groupby(['job']).apply(func)

# %%
def generate_percentage_csv(dataframe, group_by_col, target_cols, output_path):
    for key, group in dataframe.groupby(group_by_col):
        for col in target_cols:
            group = group[~group[col].isna()]
            
            if col == 'primary_proglang':
                split_df = group.assign(primary_proglang=group[col].str.split(';')).explode('primary_proglang')
                group_counts = split_df['primary_proglang'].value_counts()
                group_percentages = (group_counts / split_df.shape[0]) * 100
            
            elif col == 'db':
                split_df = group.assign(db=group[col].str.split(';')).explode('db')
                group_counts = split_df['db'].value_counts()
                group_percentages = (group_counts / split_df.shape[0]) * 100
            
            else:
                group_counts = group[col].value_counts()
                group_percentages = (group_counts / group.shape[0]) * 100
            
            result_df = group_percentages.reset_index(name='Percentage')
            result_df['Count'] = group_counts.values
            
            if isinstance(key, tuple):
                key = ''.join(key)

            cleaned_key = key.replace("(", "").replace(")", "").replace("'", "").replace(",", "")
            replaced_key = cleaned_key.replace(" ", "-").replace("/", "-")
            replaced_key = re.sub(r'-+', '-', replaced_key)

            csv_name = f"{output_path}/junior_{replaced_key}_{col}_percentages_df.csv"
            result_df.to_csv(csv_name)
            print(f"\n**{key}")
            print(f"\n**{col} 비율 (데이터프레임)**")
            display(result_df)

# %%
def calculate_and_save_percentages(df, group_by_col, target_cols, output_path):
    """
    Calculates and saves percentage distributions for specified columns in the dataframe, grouped by a specified column.

    Args:
        dataframe (pd.DataFrame): The input dataframe.
        group_by_col (str): The column to group by.
        target_cols (list of str): The target columns to calculate percentage distributions.
        output_path (str): The directory to save the output CSV files.

    Returns:
        None
    """
    for key, group in dataframe.groupby(group_by_col):
        for col in target_cols:
            group = group.loc[~group[col].isna()]
            
            if col == 'primary_proglang':
                split_df = group.assign(primary_proglang=group[col].str.split(';')).explode('primary_proglang')
                group_counts = split_df['primary_proglang'].value_counts()
                group_percentages = (group_counts / split_df.shape[0]) * 100
            
            elif col == 'db':
                split_df = group.assign(db=group[col].str.split(';')).explode('db')
                group_counts = split_df['db'].value_counts()
                group_percentages = (group_counts / split_df.shape[0]) * 100
            
            else:
                group_counts = group[col].value_counts()
                group_percentages = (group_counts / group.shape[0]) * 100
            
            result_df = group_percentages.reset_index(name='Percentage')
            result_df['Count'] = group_counts.values
            
            if isinstance(key, tuple):
                key = ''.join(key)

            cleaned_key = key.replace("(", "").replace(")", "").replace("'", "").replace(",", "")
            replaced_key = cleaned_key.replace(" ", "-").replace("/", "-")
            replaced_key = re.sub(r'-+', '-', replaced_key)

            csv_name = f"{output_path}/junior_{replaced_key}_{col}_percentages_df.csv"
            result_df.to_csv(csv_name)
            print(f"\n**{key}")
            print(f"\n**{col} 비율 (데이터프레임)**")
            display(result_df)

# Example usage:
# dataframe = pd.read_csv('path_to_your_csv.csv')
# calculate_and_save_percentages(dataframe, 'job', ['primary_proglang', 'db', 'other_column'], '../created_csv/junior')

# %%
name_format = "{key}_{col}_percentages_df"

import re
for key, group in junior_result_group_by_job.groupby(['job']):
    for col in junior_result_group_by_job.columns:
        group = group[~group[col].isna()]
        
        if col == 'primary_proglang':
            # primary_proglang 컬럼을 ;로 분리하여 개별 행을 생성
            split_df = group.assign(primary_proglang=group[col].str.split(';')).explode('primary_proglang')
            
            # Count와 Percentage 값을 각 언어별로 재분배
            group_counts = split_df['primary_proglang'].value_counts()
            group_percentages = (group_counts / split_df.shape[0]) * 100
        
        elif col == 'db':
            split_df = group.assign(db=group[col].str.split(';')).explode('db')
            
            # Count와 Percentage 값을 각 언어별로 재분배
            group_counts = split_df['db'].value_counts()
            group_percentages = (group_counts / split_df.shape[0]) * 100
 
        else:
            group_counts = group[col].value_counts()
            group_percentages = (group_counts / group.shape[0]) * 100
            
        result_df = group_percentages.reset_index(name='Percentage')
        result_df['Count'] = group_counts.values

        if isinstance(key, tuple):
            key = ''.join(key)

        cleaned_key = key.replace("(", "").replace(")", "").replace("'", "").replace(",", "")
        replaced_key = cleaned_key.replace(" ", "-").replace("/", "-")
        replaced_key = re.sub(r'-+', '-', replaced_key)

        # 데이터프레임 생성 및 출력
        result_df = group_percentages.reset_index(name='Percentage')
        result_df['Count'] = group_counts.values
        
        print(f"\n**{key}")
        print(f"\n**{col} 비율 (데이터프레임)**")
        csv_name = "../created_csv/junior/junior_{key}_{col}_percentages_df.csv".format(key=replaced_key, col=col)
        
        result_df.to_csv(csv_name)

for key, group in middle_result_group_by_job.groupby(['job']):
    for col in middle_result_group_by_job.columns:
        group = group[~group[col].isna()]
        
        if col == 'primary_proglang':
            # primary_proglang 컬럼을 ;로 분리하여 개별 행을 생성
            split_df = group.assign(primary_proglang=group[col].str.split(';')).explode('primary_proglang')
            
            # Count와 Percentage 값을 각 언어별로 재분배
            group_counts = split_df['primary_proglang'].value_counts()
            group_percentages = (group_counts / split_df.shape[0]) * 100
        
        elif col == 'db':
            split_df = group.assign(db=group[col].str.split(';')).explode('db')
            
            # Count와 Percentage 값을 각 언어별로 재분배
            group_counts = split_df['db'].value_counts()
            group_percentages = (group_counts / split_df.shape[0]) * 100
 
        else:
            group_counts = group[col].value_counts()
            group_percentages = (group_counts / group.shape[0]) * 100
            
        result_df = group_percentages.reset_index(name='Percentage')
        result_df['Count'] = group_counts.values

        if isinstance(key, tuple):
            key = ''.join(key)

        cleaned_key = key.replace("(", "").replace(")", "").replace("'", "").replace(",", "")
        replaced_key = cleaned_key.replace(" ", "-").replace("/", "-")
        replaced_key = re.sub(r'-+', '-', replaced_key)

        # 데이터프레임 생성 및 출력
        result_df = group_percentages.reset_index(name='Percentage')
        result_df['Count'] = group_counts.values
        
        print(f"\n**{key}")
        print(f"\n**{col} 비율 (데이터프레임)**")
        csv_name = "../created_csv/middle/middle_{key}_{col}_percentages_df.csv".format(key=replaced_key, col=col)
        
        result_df.to_csv(csv_name)

for key, group in senior_result_group_by_job.groupby(['job']):
    for col in senior_result_group_by_job.columns:
        group = group[~group[col].isna()]
        
        if col == 'primary_proglang':
            # primary_proglang 컬럼을 ;로 분리하여 개별 행을 생성
            split_df = group.assign(primary_proglang=group[col].str.split(';')).explode('primary_proglang')
            
            # Count와 Percentage 값을 각 언어별로 재분배
            group_counts = split_df['primary_proglang'].value_counts()
            group_percentages = (group_counts / split_df.shape[0]) * 100
        
        elif col == 'db':
            split_df = group.assign(db=group[col].str.split(';')).explode('db')
            
            # Count와 Percentage 값을 각 언어별로 재분배
            group_counts = split_df['db'].value_counts()
            group_percentages = (group_counts / split_df.shape[0]) * 100
 
        else:
            group_counts = group[col].value_counts()
            group_percentages = (group_counts / group.shape[0]) * 100
            
        result_df = group_percentages.reset_index(name='Percentage')
        result_df['Count'] = group_counts.values

        if isinstance(key, tuple):
            key = ''.join(key)

        cleaned_key = key.replace("(", "").replace(")", "").replace("'", "").replace(",", "")
        replaced_key = cleaned_key.replace(" ", "-").replace("/", "-")
        replaced_key = re.sub(r'-+', '-', replaced_key)

        # 데이터프레임 생성 및 출력
        result_df = group_percentages.reset_index(name='Percentage')
        result_df['Count'] = group_counts.values
        
        print(f"\n**{key}")
        print(f"\n**{col} 비율 (데이터프레임)**")
        csv_name = "../created_csv/senior/senior_{key}_{col}_percentages_df.csv".format(key=replaced_key, col=col)
        
        result_df.to_csv(csv_name)
# Out:
# **Data or business analyst
#
# **job_code 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **learn_time 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **edu_level 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **ide_main 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **db 비율 (데이터프레임)**
#
# **Database administrator
#
# **job_code 비율 (데이터프레임)**
#
# **Database administrator
#
# **learn_time 비율 (데이터프레임)**
#
# **Database administrator
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Database administrator
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Database administrator
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Database administrator
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Database administrator
#
# **edu_level 비율 (데이터프레임)**
#
# **Database administrator
#
# **ide_main 비율 (데이터프레임)**
#
# **Database administrator
#
# **db 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **job_code 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **learn_time 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **productive_to_job 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **primary_proglang 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **job_satisfied 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **edu_level 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **ide_main 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **db 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **job_code 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **db 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **db 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **db 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **db 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **db 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **job_code 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **learn_time 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **productive_to_job 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **primary_proglang 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **job_satisfied 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **edu_level 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **ide_main 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **db 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **job_code 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **learn_time 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **edu_level 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **ide_main 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **db 비율 (데이터프레임)**
#
# **Database administrator
#
# **job_code 비율 (데이터프레임)**
#
# **Database administrator
#
# **learn_time 비율 (데이터프레임)**
#
# **Database administrator
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Database administrator
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Database administrator
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Database administrator
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Database administrator
#
# **edu_level 비율 (데이터프레임)**
#
# **Database administrator
#
# **ide_main 비율 (데이터프레임)**
#
# **Database administrator
#
# **db 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **job_code 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **learn_time 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **productive_to_job 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **primary_proglang 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **job_satisfied 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **edu_level 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **ide_main 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **db 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **job_code 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **db 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **db 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **db 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **db 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **db 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **job_code 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **learn_time 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **productive_to_job 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **primary_proglang 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **job_satisfied 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **edu_level 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **ide_main 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **db 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **job_code 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **learn_time 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **edu_level 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **ide_main 비율 (데이터프레임)**
#
# **Data or business analyst
#
# **db 비율 (데이터프레임)**
#
# **Database administrator
#
# **job_code 비율 (데이터프레임)**
#
# **Database administrator
#
# **learn_time 비율 (데이터프레임)**
#
# **Database administrator
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Database administrator
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Database administrator
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Database administrator
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Database administrator
#
# **edu_level 비율 (데이터프레임)**
#
# **Database administrator
#
# **ide_main 비율 (데이터프레임)**
#
# **Database administrator
#
# **db 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **job_code 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **learn_time 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **productive_to_job 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **primary_proglang 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **job_satisfied 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **edu_level 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **ide_main 비율 (데이터프레임)**
#
# **DevOps specialist
#
# **db 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **job_code 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer Advocate
#
# **db 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, back-end
#
# **db 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, front-end
#
# **db 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, full-stack
#
# **db 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **job_code 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **learn_time 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **productive_to_job 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **primary_proglang 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **job_satisfied 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **edu_level 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **ide_main 비율 (데이터프레임)**
#
# **Developer, mobile
#
# **db 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **job_code 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **learn_time 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **lifestyle_sleep 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **productive_to_job 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **primary_proglang 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **job_satisfied 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **edu_level 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **ide_main 비율 (데이터프레임)**
#
# **UX / UI Designer
#
# **db 비율 (데이터프레임)**

# %% [markdown]
# result_group_by_job = jet_grouped_df.apply(s, include_groups=False)

# %% [markdown]
# ---
