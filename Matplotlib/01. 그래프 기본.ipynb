# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000002A7ECFC2EB0>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\Kang\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
#matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시 마이너스 글자 깨짐 현상 방지

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용가능한 폰트 목록 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'cmsy10',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXGeneral',
#  'cmmi10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'cmb10',
#  'STIXSizeFourSym',
#  'cmss10',
#  'DejaVu Sans',
#  'cmr10',
#  'STIXSizeFourSym',
#  'cmtt10',
#  'cmex10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'STIXSizeTwoSym',
#  'DejaVu Serif Display',
#  'STIXSizeFiveSym',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'Eras Medium ITC',
#  'KoPubDotum Light',
#  'Colonna MT',
#  'Ravie',
#  'Courier New',
#  'Microsoft YaHei',
#  'Californian FB',
#  'Consolas',
#  'Century Gothic',
#  'KoPubBatang Bold',
#  'Lucida Fax',
#  'Felix Titling',
#  'Microsoft Tai Le',
#  'Segoe UI',
#  'NanumMyeongjo',
#  'HYPMokGak-Bold',
#  'Eras Medium ITC',
#  'Ravie',
#  'Bodoni MT',
#  'HYSinMyeongJo-Medium',
#  'Lucida Sans Typewriter',
#  'Gill Sans MT Condensed',
#  'Calibri',
#  'HYPost-Medium',
#  'Cambria',
#  'Yu Gothic',
#  'Nirmala UI',
#  'Segoe UI',
#  'Bookman Old Style',
#  'Verdana',
#  'Times New Roman',
#  'Bodoni MT',
#  'Franklin Gothic Demi',
#  'Verdana',
#  'Leelawadee UI',
#  'Comic Sans MS',
#  'Segoe Print',
#  'Elephant',
#  'Calibri',
#  'High Tower Text',
#  'Segoe UI',
#  'Edwardian Script ITC',
#  'Segoe UI Variable',
#  'Gill Sans MT',
#  'SimSun-ExtB',
#  'Tw Cen MT Condensed',
#  'Courier New',
#  'Microsoft PhagsPa',
#  'Rockwell',
#  'Tw Cen MT',
#  'Franklin Gothic Heavy',
#  'Centaur',
#  'New Gulim',
#  'Times New Roman',
#  'Webdings',
#  'Calisto MT',
#  'Calisto MT',
#  'Bauhaus 93',
#  'Corbel',
#  'Comic Sans MS',
#  'Lucida Bright',
#  'Malgun Gothic',
#  'Informal Roman',
#  'NanumGothic',
#  'Headline R',
#  'Calibri',
#  'Snap ITC',
#  'Britannic Bold',
#  'Tahoma',
#  'Berlin Sans FB',
#  'HoloLens MDL2 Assets',
#  'Lucida Sans Typewriter',
#  'Microsoft Tai Le',
#  'Bodoni MT',
#  'Franklin Gothic Heavy',
#  'Vivaldi',
#  'Book Antiqua',
#  'Gloucester MT Extra Condensed',
#  'Lucida Console',
#  'Ami R',
#  'Pyunji R',
#  'Maiandra GD',
#  'Segoe Fluent Icons',
#  'Arial',
#  'Haansoft Dotum',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'Franklin Gothic Book',
#  'Ami R',
#  'Eras Light ITC',
#  'Microsoft Sans Serif',
#  'Segoe UI',
#  'Century Gothic',
#  'Corbel',
#  'HYShortSamul-Medium',
#  'Book Antiqua',
#  'MV Boli',
#  'Perpetua',
#  'Harrington',
#  'Bell MT',
#  'Gill Sans MT',
#  'Lucida Fax',
#  'HYGungSo-Bold',
#  'Eras Bold ITC',
#  'MS Outlook',
#  'Bauhaus 93',
#  'Yu Gothic',
#  'Juice ITC',
#  'Onyx',
#  'Algerian',
#  'Gabriola',
#  'Courier New',
#  'Candara',
#  'Copperplate Gothic Bold',
#  'NanumGothic',
#  'Constantia',
#  'Ebrima',
#  'Calisto MT',
#  'Tahoma',
#  'Cambria',
#  'Lucida Calligraphy',
#  'Parchment',
#  'UnDotum',
#  'Tw Cen MT',
#  'Yet R',
#  'Ebrima',
#  'Old English Text MT',
#  'Elephant',
#  'NanumGothic',
#  'Bodoni MT',
#  'HYPost-Light',
#  'SimSun',
#  'Dubai',
#  'Franklin Gothic Demi',
#  'Myanmar Text',
#  'HYGothic-Extra',
#  'Californian FB',
#  'Brush Script MT',
#  'Microsoft Himalaya',
#  'Candara',
#  'Perpetua',
#  'Gigi',
#  'Gabriola',
#  'Segoe Fluent Icons',
#  'Corbel',
#  'Palatino Linotype',
#  'Matura MT Script Capitals',
#  'KoPubDotum Medium',
#  'Microsoft New Tai Lue',
#  'Bodoni MT',
#  'Dubai',
#  'Pristina',
#  'Gulim',
#  'Imprint MT Shadow',
#  'Book Antiqua',
#  'Calibri',
#  'Elephant',
#  'Palatino Linotype',
#  'Century Gothic',
#  'Gadugi',
#  'Berlin Sans FB Demi',
#  'Informal Roman',
#  'Arial',
#  'Georgia',
#  'Magneto',
#  'Bookshelf Symbol 7',
#  'Gill Sans MT Ext Condensed Bold',
#  'Playbill',
#  'Georgia',
#  'Harrington',
#  'Bodoni MT',
#  'Consolas',
#  'KoPubBatang Medium',
#  'Rockwell',
#  'Palatino Linotype',
#  'Rage Italic',
#  'Segoe UI',
#  'Yu Gothic',
#  'Algerian',
#  'Georgia',
#  'Felix Titling',
#  'Constantia',
#  'Arial',
#  'Constantia',
#  'Parchment',
#  'Nirmala UI',
#  'Malgun Gothic',
#  'Microsoft PhagsPa',
#  'Copperplate Gothic Light',
#  'Arial',
#  'Consolas',
#  'Headline R',
#  'Calisto MT',
#  'KoPubBatang Light',
#  'Book Antiqua',
#  'Impact',
#  'Jokerman',
#  'Franklin Gothic Demi',
#  'Times New Roman',
#  'Elephant',
#  'Gloucester MT Extra Condensed',
#  'Garamond',
#  'Gill Sans Ultra Bold',
#  'Calibri',
#  'Magneto',
#  'Californian FB',
#  'Tw Cen MT',
#  'Magic R',
#  'Lucida Calligraphy',
#  'Yu Gothic',
#  'Bookman Old Style',
#  'Leelawadee UI',
#  'Trebuchet MS',
#  'Berlin Sans FB',
#  'Segoe UI',
#  'Microsoft New Tai Lue',
#  'Century Gothic',
#  'Jokerman',
#  'Tw Cen MT Condensed',
#  'Arial',
#  'Lucida Bright',
#  'MS Gothic',
#  'Edwardian Script ITC',
#  'NanumGothic',
#  'Malgun Gothic',
#  'Tw Cen MT Condensed',
#  'Century Gothic',
#  'Candara',
#  'Lucida Sans Typewriter',
#  'Bernard MT Condensed',
#  'Calisto MT',
#  'Sylfaen',
#  'Berlin Sans FB',
#  'Century Schoolbook',
#  'Gadugi',
#  'Stencil',
#  'Bodoni MT',
#  'Sitka',
#  'Castellar',
#  'Lucida Bright',
#  'Century Schoolbook',
#  'Californian FB',
#  'Californian FB',
#  'Century',
#  'KoPubBatang Medium',
#  'Nirmala UI',
#  'OCR A Extended',
#  'NanumMyeongjo',
#  'KoPubDotum Light',
#  'Gill Sans MT',
#  'Haettenschweiler',
#  'Microsoft YaHei',
#  'Bodoni MT',
#  'MS Reference Specialty',
#  'Malgun Gothic',
#  'Lucida Bright',
#  'Bell MT',
#  'Harlow Solid Italic',
#  'Calibri',
#  'Franklin Gothic Demi Cond',
#  'Freestyle Script',
#  'Courier New',
#  'NanumMyeongjo',
#  'Chiller',
#  'Niagara Solid',
#  'Segoe UI',
#  'Lucida Sans',
#  'Wide Latin',
#  'UnBatang',
#  'Britannic Bold',
#  'HYHeadLine-Medium',
#  'Palatino Linotype',
#  'Microsoft JhengHei',
#  'Candara',
#  'Lucida Fax',
#  'Yet R',
#  'MS Gothic',
#  'NanumGothic',
#  'Rage Italic',
#  'Gill Sans MT',
#  'Webdings',
#  'Candara',
#  'Lucida Bright',
#  'HYSinMyeongJo-Medium',
#  'Segoe Print',
#  'Footlight MT Light',
#  'Calibri',
#  'Franklin Gothic Book',
#  'Courier New',
#  'Consolas',
#  'BM DoHyeon',
#  'Viner Hand ITC',
#  'Segoe UI',
#  'Bodoni MT',
#  'HYGraphic-Medium',
#  'Century Schoolbook',
#  'MS Reference Specialty',
#  'Bodoni MT',
#  'Segoe UI',
#  'Rockwell Condensed',
#  'NanumGothic',
#  'Microsoft JhengHei',
#  'Cambria',
#  'Goudy Stout',
#  'Gill Sans MT',
#  'Curlz MT',
#  'Tw Cen MT',
#  'Batang',
#  'Candara',
#  'Bodoni MT',
#  'Gigi',
#  'Playbill',
#  'Segoe UI',
#  'Segoe UI',
#  'Bodoni MT',
#  'Corbel',
#  'Courier New',
#  'Eras Light ITC',
#  'Franklin Gothic Heavy',
#  'Century Schoolbook',
#  'Agency FB',
#  'Arial',
#  'Bodoni MT',
#  'Comic Sans MS',
#  'Arial',
#  'Microsoft YaHei',
#  'Constantia',
#  'Perpetua',
#  'Corbel',
#  'HYMyeongJo-Extra',
#  'Microsoft PhagsPa',
#  'Bookman Old Style',
#  'Microsoft Yi Baiti',
#  'Consolas',
#  'Lucida Console',
#  'Candara',
#  'Haettenschweiler',
#  'Consolas',
#  'Calibri',
#  'Bell MT',
#  'Tw Cen MT Condensed',
#  'Book Antiqua',
#  'Lucida Handwriting',
#  'Leelawadee UI',
#  'Calisto MT',
#  'Niagara Solid',
#  'HYGraphic-Medium',
#  'Agency FB',
#  'Blackadder ITC',
#  'Wingdings',
#  'Malgun Gothic',
#  'Candara',
#  'SimSun',
#  'Microsoft YaHei',
#  'Lucida Fax',
#  'Times New Roman',
#  'Leelawadee UI',
#  'Arial',
#  'Microsoft YaHei',
#  'Tahoma',
#  'Lucida Sans Unicode',
#  'Kunstler Script',
#  'Myanmar Text',
#  'Arial',
#  'Yu Gothic',
#  'MoeumT R',
#  'Franklin Gothic Medium Cond',
#  'Tw Cen MT',
#  'Bodoni MT',
#  'Corbel',
#  'Malgun Gothic',
#  'Cooper Black',
#  'Perpetua Titling MT',
#  'Perpetua',
#  'Calibri',
#  'Calisto MT',
#  'Comic Sans MS',
#  'Rockwell Extra Bold',
#  'Microsoft PhagsPa',
#  'Myanmar Text',
#  'Bodoni MT',
#  'NanumMyeongjo',
#  'Segoe UI',
#  'Corbel',
#  'Tw Cen MT',
#  'Century Gothic',
#  'Yu Gothic',
#  'Lucida Fax',
#  'Footlight MT Light',
#  'SimSun-ExtB',
#  'Candara',
#  'Arial Rounded MT Bold',
#  'Corbel',
#  'Segoe UI',
#  'Javanese Text',
#  'Ebrima',
#  'Lucida Sans',
#  'Verdana',
#  'Franklin Gothic Book',
#  'Poor Richard',
#  'High Tower Text',
#  'Comic Sans MS',
#  'HYHeadLine-Medium',
#  'Matura MT Script Capitals',
#  'Arial',
#  'Century Schoolbook',
#  'Gill Sans Ultra Bold',
#  'MS Reference Sans Serif',
#  'Verdana',
#  'Times New Roman',
#  'Segoe UI',
#  'Modern No. 20',
#  'Corbel',
#  'Juice ITC',
#  'Nirmala UI',
#  'Arial',
#  'Engravers MT',
#  'Georgia',
#  'Gill Sans MT Condensed',
#  'Eras Demi ITC',
#  'Nirmala UI',
#  'Segoe MDL2 Assets',
#  'Wingdings 3',
#  'Bahnschrift',
#  'NanumGothic',
#  'Berlin Sans FB',
#  'Mistral',
#  'Garamond',
#  'Bodoni MT',
#  'Franklin Gothic Book',
#  'NanumMyeongjo',
#  'High Tower Text',
#  'Imprint MT Shadow',
#  'Impact',
#  'Trebuchet MS',
#  'Segoe UI Historic',
#  'Lucida Sans',
#  'Century',
#  'MingLiU-ExtB',
#  'Bookman Old Style',
#  'Microsoft Tai Le',
#  'Times New Roman',
#  'Marlett',
#  'Segoe UI',
#  'MoeumT R',
#  'Franklin Gothic Medium',
#  'HYPost-Medium',
#  'Pristina',
#  'Mistral',
#  'Microsoft JhengHei',
#  'Calisto MT',
#  'Bernard MT Condensed',
#  'Segoe UI',
#  'NanumGothic',
#  'Symbol',
#  'Pyunji R',
#  'Segoe UI Variable',
#  'HYGothic-Medium',
#  'KoPubBatang Bold',
#  'Bookman Old Style',
#  'Bahnschrift',
#  'High Tower Text',
#  'Cambria',
#  'Garamond',
#  'Bookman Old Style',
#  'Book Antiqua',
#  'Segoe UI Emoji',
#  'Perpetua',
#  'Rockwell',
#  'Curlz MT',
#  'Tahoma',
#  'Monotype Corsiva',
#  'Garamond',
#  'Palace Script MT',
#  'Wingdings 2',
#  'Lucida Sans Unicode',
#  'Perpetua',
#  'Wide Latin',
#  'HYGungSo-Bold',
#  'Mongolian Baiti',
#  'NanumGothic',
#  'Lucida Sans',
#  'Segoe UI',
#  'Lucida Fax',
#  'Blackadder ITC',
#  'Verdana',
#  'Microsoft Himalaya',
#  'Lucida Bright',
#  'Lucida Fax',
#  'Franklin Gothic Heavy',
#  'KoPubBatang Light',
#  'MS Reference Sans Serif',
#  'UnBatang',
#  'Yu Gothic',
#  'Cambria',
#  'Dubai',
#  'Agency FB',
#  'French Script MT',
#  'Dubai',
#  'Candara',
#  'UnDotum',
#  'Bodoni MT',
#  'Arial',
#  'Eras Bold ITC',
#  'NanumGothic',
#  'Franklin Gothic Medium',
#  'Gill Sans MT',
#  'Dubai',
#  'HYPost-Light',
#  'Haansoft Dotum',
#  'Goudy Old Style',
#  'Lucida Sans Typewriter',
#  'Arial Rounded MT Bold',
#  'Forte',
#  'Modern No. 20',
#  'Bodoni MT',
#  'HYPMokGak-Bold',
#  'Microsoft JhengHei',
#  'Goudy Old Style',
#  'Lucida Sans Typewriter',
#  'Lucida Sans Typewriter',
#  'Freestyle Script',
#  'Kristen ITC',
#  'Agency FB',
#  'Bell MT',
#  'Dubai',
#  'Garamond',
#  'Rockwell',
#  'Cooper Black',
#  'Comic Sans MS',
#  'Baskerville Old Face',
#  'Century Schoolbook',
#  'Goudy Old Style',
#  'Leelawadee UI',
#  'Segoe Script',
#  'Segoe Script',
#  'Arial',
#  'Segoe UI',
#  'Brush Script MT',
#  'Candara',
#  'Lucida Bright',
#  'Chiller',
#  'Constantia',
#  'Rockwell Extra Bold',
#  'Rockwell Condensed',
#  'Perpetua Titling MT',
#  'Franklin Gothic Demi',
#  'Papyrus',
#  'Sitka',
#  'HYShortSamul-Medium',
#  'Cambria',
#  'Ebrima',
#  'Gill Sans Ultra Bold Condensed',
#  'Showcard Gothic',
#  'Book Antiqua',
#  'Microsoft Tai Le',
#  'Palatino Linotype',
#  'Perpetua Titling MT',
#  'Papyrus',
#  'Franklin Gothic Medium',
#  'Garamond',
#  'Calibri',
#  'Franklin Gothic Medium Cond',
#  'Microsoft New Tai Lue',
#  'Symbol',
#  'Courier New',
#  'Monotype Corsiva',
#  'Engravers MT',
#  'Wingdings 3',
#  'Rockwell Condensed',
#  'KoPubDotum Bold',
#  'Segoe UI',
#  'Verdana',
#  'Lucida Sans Typewriter',
#  'Bell MT',
#  'Palatino Linotype',
#  'Lucida Bright',
#  'MT Extra',
#  'Book Antiqua',
#  'Century Gothic',
#  'Dubai',
#  'Rockwell',
#  'Rockwell Condensed',
#  'Segoe Script',
#  'Franklin Gothic Demi Cond',
#  'Corbel',
#  'Tempus Sans ITC',
#  'Comic Sans MS',
#  'Goudy Old Style',
#  'Arial',
#  'Trebuchet MS',
#  'Gadugi',
#  'Segoe MDL2 Assets',
#  'Vladimir Script',
#  'Trebuchet MS',
#  'Perpetua',
#  'Georgia',
#  'Lucida Handwriting',
#  'Viner Hand ITC',
#  'Old English Text MT',
#  'Cambria',
#  'Gill Sans MT',
#  'Segoe UI',
#  'Constantia',
#  'Goudy Old Style',
#  'Script MT Bold',
#  'Arial',
#  'Wingdings',
#  'Georgia',
#  'Niagara Engraved',
#  'New Gulim',
#  'NanumGothic',
#  'Broadway',
#  'Segoe UI Historic',
#  'Microsoft Sans Serif',
#  'Bookshelf Symbol 7',
#  'HYGothic-Extra',
#  'Harlow Solid Italic',
#  'Ink Free',
#  'Onyx',
#  'Bookman Old Style',
#  'Kunstler Script',
#  'Copperplate Gothic Light',
#  'Constantia',
#  'Bodoni MT',
#  'Mongolian Baiti',
#  'MS Outlook',
#  'Rockwell',
#  'Segoe UI Emoji',
#  'Colonna MT',
#  'Microsoft JhengHei',
#  'Tw Cen MT',
#  'NanumGothic',
#  'Californian FB',
#  'Trebuchet MS',
#  'Consolas',
#  'Segoe UI',
#  'Rockwell',
#  'Verdana',
#  'Times New Roman',
#  'Berlin Sans FB Demi',
#  'Snap ITC',
#  'HYMyeongJo-Extra',
#  'Trebuchet MS',
#  'NanumMyeongjo',
#  'MT Extra',
#  'Lucida Fax',
#  'Gill Sans MT',
#  'Segoe UI',
#  'Microsoft New Tai Lue',
#  'Niagara Engraved',
#  'Lucida Sans',
#  'Century Schoolbook',
#  'Trebuchet MS',
#  'Sitka',
#  'Castellar',
#  'Verdana',
#  'Times New Roman',
#  'Bradley Hand ITC',
#  'Palatino Linotype',
#  'Script MT Bold',
#  'Forte',
#  'OCR A Extended',
#  'Georgia',
#  'Palatino Linotype',
#  'Century Schoolbook',
#  'Lucida Sans',
#  'Vladimir Script',
#  'Tw Cen MT',
#  'Candara',
#  'Nirmala UI',
#  'Tw Cen MT Condensed Extra Bold',
#  'HYGothic-Medium',
#  'Gill Sans Ultra Bold Condensed',
#  'Arial',
#  'Calibri',
#  'Constantia',
#  'Goudy Old Style',
#  'HoloLens MDL2 Assets',
#  'Centaur',
#  'Sylfaen',
#  'Arial',
#  'Wingdings 2',
#  'Gadugi',
#  'Corbel',
#  'Copperplate Gothic Bold',
#  'Bodoni MT',
#  'Ink Free',
#  'Bodoni MT',
#  'Vivaldi',
#  'Gulim',
#  'Franklin Gothic Medium',
#  'Lucida Sans Typewriter',
#  'Rockwell',
#  'Dubai',
#  'Goudy Stout',
#  'Myanmar Text',
#  'Bodoni MT',
#  'Maiandra GD',
#  'Gill Sans MT Ext Condensed Bold',
#  'Microsoft Yi Baiti',
#  'Bradley Hand ITC',
#  'Perpetua',
#  'Trebuchet MS',
#  'Yu Gothic',
#  'Perpetua Titling MT',
#  'Poor Richard',
#  'Tw Cen MT Condensed Extra Bold',
#  'Cambria',
#  'Calibri',
#  'Magic R',
#  'Showcard Gothic',
#  'Comic Sans MS',
#  'Segoe UI Symbol',
#  'Palace Script MT',
#  'Segoe UI Symbol',
#  'Kristen ITC',
#  'Corbel',
#  'Microsoft JhengHei',
#  'NanumMyeongjo',
#  'Bookman Old Style',
#  'Lucida Sans',
#  'NanumMyeongjo',
#  'Segoe Print',
#  'Tempus Sans ITC',
#  'MV Boli',
#  'KoPubDotum Bold',
#  'Georgia',
#  'KoPubDotum Medium',
#  'MingLiU-ExtB',
#  'Stencil',
#  'Leelawadee UI',
#  'Batang',
#  'Broadway',
#  'Century Gothic',
#  'Sitka',
#  'Bell MT',
#  'French Script MT',
#  'Consolas',
#  'Eras Demi ITC',
#  'Segoe Script',
#  'Segoe UI',
#  'Javanese Text',
#  'Lucida Sans',
#  'Baskerville Old Face',
#  'Segoe Print',
#  'Arial',
#  'Courier New']

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, -2])
