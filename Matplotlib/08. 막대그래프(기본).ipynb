# %% [markdown]
# # 8. 막대그래프 (기본)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
#matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시 마이너스 글자 깨짐 현상 방지

# %%
labels = ['강병호', '이병헌', '김세환'] # 이름
values = [177, 180, 183 ] # 키

plt.bar(labels, values) #막대그래프
plt.show()

# %%
labels = ['강병호', '이병헌', '김세환'] # 이름
values = [177, 180, 183 ] # 키

plt.bar(labels, values, color = 'r') #막대그래프]
plt.show()

# %%
labels = ['강병호', '이병헌', '김세환'] # 이름
values = [177, 180, 183 ] # 키
colors = ['r', 'g', 'b'] # 각각의 색깔

plt.bar(labels, values, color = colors, alpha = 0.5) #막대그래프]
plt.show()

# %%
labels = ['강병호', '이병헌', '김세환'] # 이름
values = [177, 180, 183 ] # 키

plt.bar(labels, values) #막대그래프
plt.ylim(175, 185) # 범위 설정
plt.show()

# %%
plt.bar(labels, values, width = 0.5) #막대그래프
plt.ylim(175, 185) # 범위 설정
plt.show()

# %%
plt.bar(labels, values, width = 0.3)
plt.xticks(rotation = 45 ) # x축의 이름데이터 각도를 45도로 설정
plt.yticks(rotation = 45 ) # y축의 이름데이터 각도를 45도로 설정
plt.show()

# %%
ticks = ['1번학생', '2번학생', '3번학생']
plt.bar(labels, values, width = 0.3)
plt.xticks(labels, ticks) # x 축
plt.show()

# %%
ticks = ['1번학생', '2번학생', '3번학생']
plt.bar(labels, values, width = 0.3)
plt.xticks(labels, ticks, rotation = 90) # x 축
plt.show()
